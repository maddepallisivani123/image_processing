# %% [markdown]
# <a href="https://colab.research.google.com/github/maddepallisivani123/image_processing/blob/main/maddepallisivani123_image_processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread("rose.png", cv2.IMREAD_COLOR)
plt.imshow(img)

# %%
img2 = cv2.imread("rose.png", cv2.IMREAD_GRAYSCALE)

# %%
sobel = cv2.Sobel(img,cv2.CV_64F,1,0,ksize=5)

# %%
plt.imshow(img2)

# %%
plt.subplot(1,1,1),plt.imshow(sobel,cmap = 'gray')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f01dad08c10>,
#  <matplotlib.image.AxesImage at 0x7f01dacbf910>)
